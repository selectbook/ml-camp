# %% [markdown]
# ## 七月在线机器学习实训营三期第四周(数据可视化及拟合)考试
# #### 考试说明:
# - 起止时间：请同学在2018年3月2日至3月4日期间完成，最晚提交时间本周日（3月4日24时之前）结束，<b>逾期不接受补考,该考试分数计入平时成绩</b>
# - 考试方式：请同学<font color=red><b>拷贝</b></font>该试卷至自己姓名的目录后，将文件更名为同学姓名拼音-exam4后，进行作答。例如wangwei-exam4
# - 提交格式：请同学新建自己姓名全拼的文件夹，将该试卷，zip文件等相关考试文件，放置此目录下。将该目录<b>移动</b>至/0.Teacher/Exam/4/目录下
# - 注意事项：为确保同学们真正了解自身对本周课程的掌握程度，<font color=red><b>请勿翻阅，移动，更改</b></font>其它同学试卷。如发现按0分处理
# - 请同学在下方同学姓名处填写自己的姓名，批改人和最终得分不用填写

# %% [markdown]
# - 同学姓名:<u> 胡振彪</u>
# - 批改人： David
# - 最终得分:93

# %% [markdown]
# <center><h1>####答卷开始####</h1></center>
# <hr>

# %% [markdown]
# ## 问答题(共5题，每题4分，共计20分)
#
# - note:
# 18分

# %% [markdown]
# ### 1.谈谈您对数据可视，以及其对数据分析，机器学习的意义的理解

# %% [markdown]
# -  数据可视化是指以柱状图、饼状图、线型图等图形方式展示数据，更利于决策者使用，让决策者更高效的了解数据的重要信息和细节层次。
# - 数据分析是采用用适当的统计分析方法对收集来的大量数据进行分析，从而提取有用信息和形成结论。通俗的来说，就是借助数据，分析数据特点，来指导决策。
# - 机器学习在人工智能的研究中具有十分重要的地位，也是整个数据相关行业很重要的一部分。是在数据清理、数据分析、数据可视化、数据报告等后有一个重要环节。侧重于使用现有数据和模型对未来的预测。

# %% [markdown]
# ### 2.某评测网站对市场上某品牌充电宝随机抽取30款测得其使用寿命数据，请问哪些可视化方案适宜呈现该结果？这些方案透露出了哪些含义

# %% [markdown]
# *** 使用柱状图、箱型图绘制图充电宝的使用寿命分布，可以粗略地看出数据是分布的分散程度等信息以及其他统计学信息。

# %% [markdown]
# ### 3.	一组数据的分布特征可以从哪几个方面进行描述？

# %% [markdown]
# ***数据分布的特征可以从三个方面进行测度和描述：
# 1.分布的集中趋势，反映各数据向其中心值靠拢或聚集的程度；
# 2.分布的离散程度，反映各数据远离其中心值的趋势；
# 3.分布的形状，反映数据分布的偏态和峰态
# （百度答案）

# %% [markdown]
# ### 4.（接上题）如何从可视化的角度解读一组数据的分布特征？(代码演示有额外加分)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns

x = np.random.normal(size=100)
sns.distplot(x, kde=True)

# %% [markdown]
# ### 5.简要谈谈您对seaborn库的理解，以及有哪些较高级的用法。(代码演示有额外加分)

# %% [markdown]
# - seaborn是实在matplotlib的基础上的完善，更多高级绘图功能的封装，使用起来更方便。有很多高级功能，
# - 高级功能诸如：单因素的核密度估计、双变量分布中六角形图、pairplot等。

# %%
iris = sns.load_dataset("iris")
iris.head()
sns.pairplot(iris);

# %% [markdown]
# ## 实战题(共四题，每题20分)
# #### (注意:题目均要求使用seaborn库进行)
#
# - note:
# 70分

# %% [markdown]
# ### 1.航班乘客变化分析

# %% [markdown]
# - 载入相应绘图库及航班乘客数据（flights）

# %%
# your code
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(style="white", color_codes=True)
plt.rcParams["figure.figsize"] = (12,6)

# %%
data = sns.load_dataset('flights')
data.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %% [markdown]
# - 分析年度乘客总量变化情况（折线图）
#
# - note:
# 应该对总数据做下处理。比如进行求和或求平均

# %%
# your code
sns.pointplot(x = 'year',y = 'passengers',data = data, ci = False)

# %% [markdown]
# - 分析乘客在一年中各月份的分布（柱状图）

# %%
# your code
sns.barplot(x = 'month',y = 'passengers',data= data )

# %% [markdown]
# ### 2.鸢尾花花型尺寸分析
#
# * 载入iris数据集
# * 萼片（sepal）和花瓣（petal）的大小关系（散点图）
# - 不同种类鸢尾花萼片和花瓣大小的分布情况（柱状图或者箱式图）
# * 不同种类（species）鸢尾花萼片和花瓣的大小关系（分类散点子图）

# %%
# your code
#载入iris数据集
data = sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data['sepal_size']=data['sepal_length']*data['sepal_length']
data['petal_size']=data['petal_length']*data['petal_length']
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal  petal  \
# 0           5.1          3.5           1.4          0.2  setosa  26.01   1.96
# 1           4.9          3.0           1.4          0.2  setosa  24.01   1.96
# 2           4.7          3.2           1.3          0.2  setosa  22.09   1.69
# 3           4.6          3.1           1.5          0.2  setosa  21.16   2.25
# 4           5.0          3.6           1.4          0.2  setosa  25.00   1.96
#
#    sepal_size  petal_size
# 0       26.01        1.96
# 1       24.01        1.96
# 2       22.09        1.69
# 3       21.16        2.25
# 4       25.00        1.96

# %%
#萼片（sepal）和花瓣（petal）的大小关系（散点图）
sns.lmplot(x='sepal_size',y='petal_size',data=data)

# %%
#不同种类鸢尾花萼片和花瓣大小的分布情况（柱状图或者箱式图）
g = sns.PairGrid(data,
                 x_vars=["species"],
                 y_vars=["sepal_size", "petal_size"],
                 aspect=2, size=4)
g.map(sns.barplot, palette="pastel");

# %%
# 不同种类（species）鸢尾花萼片和花瓣的大小关系（分类散点子图）
# your code
sns.lmplot(x="sepal_length", y="petal_length", hue="species", data=data)

# %% [markdown]
# ### 3.餐厅小费情况分析
# * 载入tips数据集
# * 小费和总消费之间的关系（散点图）
# * 男性顾客和女性顾客，谁更慷慨（分类箱式图）
# * 抽烟与否是否会对小费金额产生影响（分类箱式图）
# * 工作日和周末，什么时候顾客给的小费更慷慨（分类箱式图）
# * 午饭和晚饭，哪一顿顾客更愿意给小费（分类箱式图）
# * 就餐人数是否会对慷慨度产生影响（分类箱式图）
# * 性别+抽烟的组合因素对慷慨度的影响（分组柱状图）

# %%
# your code
data  = sns.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#小费和总消费之间的关系（散点图）
sns.lmplot(x='total_bill',y='tip',data=data)

# %%
# 男性顾客和女性顾客，谁更慷慨（分类箱式图）
sns.boxplot(x='sex',y='tip',data=data)
plt.rcParams["figure.figsize"] = (8,5)

# %%
# 抽烟与否是否会对小费金额产生影响
sns.boxplot(x='smoker',y='tip',data=data)

# %%
# 工作日和周末，什么时候顾客给的小费更慷慨（分类箱式图）
day = data['day'].unique()
day
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
data_week = pd.DataFrame(('weekend'if x in ['Sun', 'Sat'] else 'weekday' for x in data.day), index = data.index,columns = ['week'])
data=pd.merge(data,data_week,left_index=True,right_index=True)
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   week_x   week_y  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2  weekend  weekend
# 1       10.34  1.66    Male     No  Sun  Dinner     3  weekend  weekend
# 2       21.01  3.50    Male     No  Sun  Dinner     3  weekend  weekend
# 3       23.68  3.31    Male     No  Sun  Dinner     2  weekend  weekend
# 4       24.59  3.61  Female     No  Sun  Dinner     4  weekend  weekend
#
#       week
# 0  weekend
# 1  weekend
# 2  weekend
# 3  weekend
# 4  weekend

# %%
sns.boxplot(x='week',y='tip',data=data )

# %%
#午饭和晚饭，哪一顿顾客更愿意给小费（分类箱式图）
sns.boxplot(x='time',y='tip',data=data )

# %%
# 就餐人数是否会对慷慨度产生影响（分类箱式图）
sns.boxplot(x='size',y='tip',data=data )

# %%
# 性别+抽烟的组合因素对慷慨度的影响（分组柱状图）
sns.barplot(x='sex',y='tip',hue='smoker',data=data)

# %% [markdown]
# ### 4.泰坦尼克号海难幸存状况分析
# * 不同仓位等级中幸存和遇难的乘客比例（堆积柱状图）
# * 不同性别的幸存比例（堆积柱状图）
# * 幸存和遇难乘客的票价分布（分类箱式图）
# * 幸存和遇难乘客的年龄分布（分类箱式图）
# * 不同上船港口的乘客仓位等级分布（分组柱状图）
# * 幸存和遇难乘客堂兄弟姐妹的数量分布（分类箱式图）
# * 幸存和遇难乘客父母子女的数量分布（分类箱式图）
# * 单独乘船与否和幸存之间有没有联系（堆积柱状图或者分组柱状图）

# %%
# your code
data = sns.load_dataset('titanic')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#不同仓位等级中幸存和遇难的乘客比例（堆积柱状图） 此处seaborn绘制模板没有 故使用matplotlib
# 绘制堆积柱状图
def stackedbarplot(x_data, y_data_list, y_data_names, colors, x_label, y_label, title):
    _, ax = plt.subplots()
    # 循环绘制堆积柱状图
    for i in range(0, len(y_data_list)):
        if i == 0:
            ax.bar(x_data, y_data_list[i], color = colors[i], align = 'center', label = y_data_names[i])
        else:
            # 采用堆积的方式，除了第一个分类，后面的分类都从前一个分类的柱状图接着画
            # 用归一化保证最终累积结果为1
            ax.bar(x_data, y_data_list[i], color = colors[i], bottom = y_data_list[i - 1], align = 'center', label = y_data_names[i])
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
    ax.legend(loc = 'upper right') # 设定图例位置
    
pclass_survived=data.groupby(['pclass','survived']).size().unstack()
pclass_survived
# Out:
# survived    0    1
# pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pclass_survived['sum']=pclass_survived[0]+pclass_survived[1]
pclass_survived['yes_prop']=pclass_survived[1]/pclass_survived['sum']
pclass_survived['no_prop']=pclass_survived[0]/pclass_survived['sum']
pclass_survived
# Out:
# survived    0    1  sum  yes_prop   no_prop
# pclass
# 1          80  136  216  0.629630  0.370370
# 2          97   87  184  0.472826  0.527174
# 3         372  119  491  0.242363  0.757637

# %%
# 调用绘图函数
stackedbarplot(x_data = pclass_survived.index.values
               , y_data_list = [pclass_survived['yes_prop'], pclass_survived['no_prop']]
               , y_data_names = ['Survived', 'Not survived']
               , colors = ['#539caf', '#7663b0']
               , x_label = 'Pclass'
               , y_label = 'Number of People'
               , title = 'Number of People By Survived Or Not by Pclass')

ax=plt.gca() # get current figure
ax.set_xticks(range(1,4))
ax.set_xticklabels(pclass_survived.index.values)
plt.rcParams["figure.figsize"] = (10,6)
plt.legend(loc = 'best')

# %%
# 不同性别的幸存比例（堆积柱状图）
sex_survived=data.groupby(['sex','survived']).size().unstack()
sex_survived
# Out:
# survived    0    1
# sex
# female     81  233
# male      468  109

# %%
sex_survived['sum']=sex_survived[0]+sex_survived[1]
sex_survived['yes_prop']=sex_survived[1]/sex_survived['sum']
sex_survived['no_prop']=sex_survived[0]/sex_survived['sum']
sex_survived
# Out:
# survived    0    1  sum  yes_prop   no_prop
# sex
# female     81  233  314  0.742038  0.257962
# male      468  109  577  0.188908  0.811092

# %%
# 调用绘图函数
stackedbarplot(x_data = [0,1]
               , y_data_list = [sex_survived['yes_prop'], sex_survived['no_prop']]
               , y_data_names = ['Survived', 'Not survived']
               , colors = ['#539caf', '#7663b0']
               , x_label = 'Sex'
               , y_label = 'Number of People'
               , title = 'Number of People By Survived Or Not by Sex')
ax=plt.gca()
ax.set_xticks(range(2))
ax.set_xticklabels(sex_survived.index.values)
plt.rcParams["figure.figsize"] = (8,8)

# %%
# 幸存和遇难乘客的票价分布（分类箱式图）
sns.boxplot(x='alive',y='fare',data=data)
plt.rcParams["figure.figsize"] = (8,5)

# %%
#幸存和遇难乘客的年龄分布（分类箱式图）
sns.boxplot(x = 'alive', y = 'age',data = data)

# %%
# 不同上船港口的乘客仓位等级分布（分组柱状图）
sns.barplot(x='embarked',y='pclass',data=data)

# %%
#幸存和遇难乘客堂兄弟姐妹的数量分布（分类箱式图）
sns.boxplot(x='alive',y='sibsp',data=data)

# %%
#幸存和遇难乘客父母子女的数量分布（分类箱式图）
sns.boxplot(x='alive',y='parch',data=data)

# %%
#单独乘船与否和幸存之间有没有联系（堆积柱状图或者分组柱状图）
sns.barplot(x='alone',y='survived',data=data)

# %% [markdown]
# ### 本阶段课程意见反馈题(10分送分项，非必答)
# #### 请同学围绕以下两点进行回答：
# - 自身总结：请您对您自己在本周课程的学习，收获，技能掌握等方面进行一次总结 ，也包括有哪些方面存在哪些不足，欠缺，困惑。作为将来回顾学习路径时的依据。

# %% [markdown]
# - 本周主要学习了使用matplotlib、seaborn两个常用的数据分析绘图软件
# - 知识点太多，一时不知道如何下手绘图，只能调用模板，好多参数设置不熟悉

# %% [markdown]
# - 课程反馈：请就知识点，进度，难易度，教学方式，考试方式及难易度等方面向我们反馈，督促我们进行更有效的改进。

# %% [markdown]
# - 认真的来讲，课程内容很多，对于转行的学生来说，刚刚接触很难搞的明白，比如画图，一周学习下来，可能只是会使用模板吧。
# - 因此建议在课前把一周的内容全部放进去云平台这样便于预习，同时希望老师能够推荐一些由浅入深的参考书籍，
# - 希望老师针对性的多讲解例题事例，事例讲解效果更好。

# %% [markdown]
# <hr>
# <center><h1>####答卷结束####</h1></center>
