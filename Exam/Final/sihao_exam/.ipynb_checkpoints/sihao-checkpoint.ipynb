# %% [markdown]
# #### 本次成绩:95
#
# ### 评卷标准:
# - 分析，理顺，项目要求并落实在文档中   这个这个，体现得不好。 技术思维比较重些。
# - 比较不同结果 ，思考，改进，总结。   √
# - 成绩提交并截图成绩   √这个点赞，成绩好棒
# - 最终结论，报告。    这个，这个。。。
# - 参考kernel，+10
#
# 成绩top100，棒。。但整个项目如果把思路指导，体现在层次结构 中，并参考其它满分同学的思路。加上你这个成绩，无敌了。
# 彭志雄就做得很好，有成绩，有思路。你看看
#
# #### 评卷：David

# %%
#先是自己做了特征工程，发现效果很一般，还很浪费时间，随后直接参考了一个排名75给出的kernel
#kernel：  https://www.kaggle.com/harunshimanto/house-price-prediction 
#自己的尝试部分：
#（1）在该kernel的特征处理基础上，尝试用dnn去解决
#（2）用xgboost网格搜索训练，发现效果并不好 
#（3）在源代码上融合DNN的sklearn的model
#以下参考直接参考的过程代码在前面加【参考】标记

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.style.use('ggplot')

# %%
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline, make_pipeline
from scipy.stats import skew
from sklearn.decomposition import PCA, KernelPCA
from sklearn.preprocessing import Imputer

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import SVR, LinearSVR
from sklearn.linear_model import ElasticNet, SGDRegressor, BayesianRidge
from sklearn.kernel_ridge import KernelRidge

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
#【参考】
train.drop(train[(train["GrLivArea"]>4000)&(train["SalePrice"]<300000)].index,inplace=True)

# %%
#【参考】
full=pd.concat([train,test], ignore_index=True)
full.drop(['Id'],axis=1, inplace=True)

# %%
#【参考】
full["LotAreaCut"] = pd.qcut(full.LotArea,10)

# %%
#【参考】
# Since some combinations of LotArea and Neighborhood are not available, so we just LotAreaCut alone.
full['LotFrontage']=full.groupby(['LotAreaCut'])['LotFrontage'].transform(lambda x: x.fillna(x.median()))

cols=["MasVnrArea", "BsmtUnfSF", "TotalBsmtSF", "GarageCars", "BsmtFinSF2", "BsmtFinSF1", "GarageArea"]
for col in cols:
    full[col].fillna(0, inplace=True)

cols1 = ["PoolQC" , "MiscFeature", "Alley", "Fence", "FireplaceQu", "GarageQual", "GarageCond", "GarageFinish", "GarageYrBlt", "GarageType", "BsmtExposure", "BsmtCond", "BsmtQual", "BsmtFinType2", "BsmtFinType1", "MasVnrType"]
for col in cols1:
    full[col].fillna("None", inplace=True)

# fill in with mode
cols2 = ["MSZoning", "BsmtFullBath", "BsmtHalfBath", "Utilities", "Functional", "Electrical", "KitchenQual", "SaleType","Exterior1st", "Exterior2nd"]
for col in cols2:
    full[col].fillna(full[col].mode()[0], inplace=True)

# %%
#【参考】
NumStr = ["MSSubClass","BsmtFullBath","BsmtHalfBath","HalfBath","BedroomAbvGr","KitchenAbvGr","MoSold","YrSold","YearBuilt","YearRemodAdd","LowQualFinSF","GarageYrBlt"]
for col in NumStr:
    full[col]=full[col].astype(str)

# %%
#【参考】
def map_values():
    full["oMSSubClass"] = full.MSSubClass.map({'180':1, 
                                        '30':2, '45':2, 
                                        '190':3, '50':3, '90':3, 
                                        '85':4, '40':4, '160':4, 
                                        '70':5, '20':5, '75':5, '80':5, '150':5,
                                        '120': 6, '60':6})
    
    full["oMSZoning"] = full.MSZoning.map({'C (all)':1, 'RH':2, 'RM':2, 'RL':3, 'FV':4})
    
    full["oNeighborhood"] = full.Neighborhood.map({'MeadowV':1,
                                               'IDOTRR':2, 'BrDale':2,
                                               'OldTown':3, 'Edwards':3, 'BrkSide':3,
                                               'Sawyer':4, 'Blueste':4, 'SWISU':4, 'NAmes':4,
                                               'NPkVill':5, 'Mitchel':5,
                                               'SawyerW':6, 'Gilbert':6, 'NWAmes':6,
                                               'Blmngtn':7, 'CollgCr':7, 'ClearCr':7, 'Crawfor':7,
                                               'Veenker':8, 'Somerst':8, 'Timber':8,
                                               'StoneBr':9,
                                               'NoRidge':10, 'NridgHt':10})
    
    full["oCondition1"] = full.Condition1.map({'Artery':1,
                                           'Feedr':2, 'RRAe':2,
                                           'Norm':3, 'RRAn':3,
                                           'PosN':4, 'RRNe':4,
                                           'PosA':5 ,'RRNn':5})
    
    full["oBldgType"] = full.BldgType.map({'2fmCon':1, 'Duplex':1, 'Twnhs':1, '1Fam':2, 'TwnhsE':2})
    
    full["oHouseStyle"] = full.HouseStyle.map({'1.5Unf':1, 
                                           '1.5Fin':2, '2.5Unf':2, 'SFoyer':2, 
                                           '1Story':3, 'SLvl':3,
                                           '2Story':4, '2.5Fin':4})
    
    full["oExterior1st"] = full.Exterior1st.map({'BrkComm':1,
                                             'AsphShn':2, 'CBlock':2, 'AsbShng':2,
                                             'WdShing':3, 'Wd Sdng':3, 'MetalSd':3, 'Stucco':3, 'HdBoard':3,
                                             'BrkFace':4, 'Plywood':4,
                                             'VinylSd':5,
                                             'CemntBd':6,
                                             'Stone':7, 'ImStucc':7})
    
    full["oMasVnrType"] = full.MasVnrType.map({'BrkCmn':1, 'None':1, 'BrkFace':2, 'Stone':3})
    
    full["oExterQual"] = full.ExterQual.map({'Fa':1, 'TA':2, 'Gd':3, 'Ex':4})
    
    full["oFoundation"] = full.Foundation.map({'Slab':1, 
                                           'BrkTil':2, 'CBlock':2, 'Stone':2,
                                           'Wood':3, 'PConc':4})
    
    full["oBsmtQual"] = full.BsmtQual.map({'Fa':2, 'None':1, 'TA':3, 'Gd':4, 'Ex':5})
    
    full["oBsmtExposure"] = full.BsmtExposure.map({'None':1, 'No':2, 'Av':3, 'Mn':3, 'Gd':4})
    
    full["oHeating"] = full.Heating.map({'Floor':1, 'Grav':1, 'Wall':2, 'OthW':3, 'GasW':4, 'GasA':5})
    
    full["oHeatingQC"] = full.HeatingQC.map({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5})
    
    full["oKitchenQual"] = full.KitchenQual.map({'Fa':1, 'TA':2, 'Gd':3, 'Ex':4})
    
    full["oFunctional"] = full.Functional.map({'Maj2':1, 'Maj1':2, 'Min1':2, 'Min2':2, 'Mod':2, 'Sev':2, 'Typ':3})
    
    full["oFireplaceQu"] = full.FireplaceQu.map({'None':1, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5})
    
    full["oGarageType"] = full.GarageType.map({'CarPort':1, 'None':1,
                                           'Detchd':2,
                                           '2Types':3, 'Basment':3,
                                           'Attchd':4, 'BuiltIn':5})
    
    full["oGarageFinish"] = full.GarageFinish.map({'None':1, 'Unf':2, 'RFn':3, 'Fin':4})
    
    full["oPavedDrive"] = full.PavedDrive.map({'N':1, 'P':2, 'Y':3})
    
    full["oSaleType"] = full.SaleType.map({'COD':1, 'ConLD':1, 'ConLI':1, 'ConLw':1, 'Oth':1, 'WD':1,
                                       'CWD':2, 'Con':3, 'New':3})
    
    full["oSaleCondition"] = full.SaleCondition.map({'AdjLand':1, 'Abnorml':2, 'Alloca':2, 'Family':2, 'Normal':3, 'Partial':4})  
    return "Done!"

# %%
#【参考】
map_values()
# Out:
# 'Done!'

# %%
#【参考】
# drop two unwanted columns
full.drop("LotAreaCut",axis=1,inplace=True)
full.drop(['SalePrice'],axis=1,inplace=True)

# %%
#【参考】
class labelenc(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
    
    def fit(self,X,y=None):
        return self
    
    def transform(self,X):
        lab=LabelEncoder()
        X["YearBuilt"] = lab.fit_transform(X["YearBuilt"])
        X["YearRemodAdd"] = lab.fit_transform(X["YearRemodAdd"])
        X["GarageYrBlt"] = lab.fit_transform(X["GarageYrBlt"])
        return X

# %%
#【参考】
class skew_dummies(BaseEstimator, TransformerMixin):
    def __init__(self,skew=0.5):
        self.skew = skew
    
    def fit(self,X,y=None):
        return self
    
    def transform(self,X):
        X_numeric=X.select_dtypes(exclude=["object"])
        skewness = X_numeric.apply(lambda x: skew(x))
        skewness_features = skewness[abs(skewness) >= self.skew].index
        X[skewness_features] = np.log1p(X[skewness_features])
        X = pd.get_dummies(X)
        return X

# %%
#【参考】
# build pipeline
pipe = Pipeline([
    ('labenc', labelenc()),
    ('skew_dummies', skew_dummies(skew=1)),
    ])

# %%
#【参考】
# save the original data for later use
full2 = full.copy()

# %%
#【参考】
data_pipe = pipe.fit_transform(full2)

data_pipe.shape
# Out:
# (2917, 405)

# %%
#【参考】  这里尝试用我们一般是使用的标准化，发现效果一般，去掉log后不可以收敛 ，又改回来了
scaler = RobustScaler()

n_train=train.shape[0]

X = data_pipe[:n_train]
test_X = data_pipe[n_train:]
y= train.SalePrice

X_scaled = scaler.fit(X).transform(X)
y_log = np.log(train.SalePrice)
test_X_scaled = scaler.transform(test_X)

# %%
#【参考】
#Feature Selection
lasso=Lasso(alpha=0.001)
lasso.fit(X_scaled,y_log)
FI_lasso = pd.DataFrame({"Feature Importance":lasso.coef_}, index=data_pipe.columns)

FI_lasso.sort_values("Feature Importance",ascending=False)
# Out:
#                        Feature Importance
# GrLivArea                        0.108331
# OverallQual                      0.102471
# 2ndFlrSF                         0.074367
# YearBuilt                        0.068877
# 1stFlrSF                         0.059729
# Functional_Typ                   0.051691
# TotalBsmtSF                      0.050464
# Neighborhood_Crawfor             0.049867
# OverallCond                      0.045507
# oNeighborhood                    0.044366
# Exterior1st_BrkFace              0.044081
# oSaleCondition                   0.041490
# BsmtFinSF1                       0.040845
# BsmtQual_Ex                      0.039833
# oMSZoning                        0.039764
# KitchenQual_Ex                   0.039394
# Neighborhood_BrkSide             0.037999
# BsmtExposure_Gd                  0.033778
# Condition1_Norm                  0.033597
# LotArea                          0.027483
# GarageCars                       0.024517
# ...

# %%
#【参考】
FI_lasso[FI_lasso["Feature Importance"]!=0].sort_values("Feature Importance").plot(kind="barh",figsize=(15,25))
plt.xticks(rotation=90)
plt.show()

# %%
#【参考】
class add_feature(BaseEstimator, TransformerMixin):
    def __init__(self,additional=1):
        self.additional = additional
    
    def fit(self,X,y=None):
        return self
    
    def transform(self,X):
        if self.additional==1:
            X["TotalHouse"] = X["TotalBsmtSF"] + X["1stFlrSF"] + X["2ndFlrSF"]   
            X["TotalArea"] = X["TotalBsmtSF"] + X["1stFlrSF"] + X["2ndFlrSF"] + X["GarageArea"]
            
        else:
            X["TotalHouse"] = X["TotalBsmtSF"] + X["1stFlrSF"] + X["2ndFlrSF"]   
            X["TotalArea"] = X["TotalBsmtSF"] + X["1stFlrSF"] + X["2ndFlrSF"] + X["GarageArea"]
            
            X["+_TotalHouse_OverallQual"] = X["TotalHouse"] * X["OverallQual"]
            X["+_GrLivArea_OverallQual"] = X["GrLivArea"] * X["OverallQual"]
            X["+_oMSZoning_TotalHouse"] = X["oMSZoning"] * X["TotalHouse"]
            X["+_oMSZoning_OverallQual"] = X["oMSZoning"] + X["OverallQual"]
            X["+_oMSZoning_YearBuilt"] = X["oMSZoning"] + X["YearBuilt"]
            X["+_oNeighborhood_TotalHouse"] = X["oNeighborhood"] * X["TotalHouse"]
            X["+_oNeighborhood_OverallQual"] = X["oNeighborhood"] + X["OverallQual"]
            X["+_oNeighborhood_YearBuilt"] = X["oNeighborhood"] + X["YearBuilt"]
            X["+_BsmtFinSF1_OverallQual"] = X["BsmtFinSF1"] * X["OverallQual"]
            
            X["-_oFunctional_TotalHouse"] = X["oFunctional"] * X["TotalHouse"]
            X["-_oFunctional_OverallQual"] = X["oFunctional"] + X["OverallQual"]
            X["-_LotArea_OverallQual"] = X["LotArea"] * X["OverallQual"]
            X["-_TotalHouse_LotArea"] = X["TotalHouse"] + X["LotArea"]
            X["-_oCondition1_TotalHouse"] = X["oCondition1"] * X["TotalHouse"]
            X["-_oCondition1_OverallQual"] = X["oCondition1"] + X["OverallQual"]
            
           
            X["Bsmt"] = X["BsmtFinSF1"] + X["BsmtFinSF2"] + X["BsmtUnfSF"]
            X["Rooms"] = X["FullBath"]+X["TotRmsAbvGrd"]
            X["PorchArea"] = X["OpenPorchSF"]+X["EnclosedPorch"]+X["3SsnPorch"]+X["ScreenPorch"]
            X["TotalPlace"] = X["TotalBsmtSF"] + X["1stFlrSF"] + X["2ndFlrSF"] + X["GarageArea"] + X["OpenPorchSF"]+X["EnclosedPorch"]+X["3SsnPorch"]+X["ScreenPorch"]

    
            return X

   
pipe = Pipeline([
    ('labenc', labelenc()),
    ('add_feature', add_feature(additional=2)),
    ('skew_dummies', skew_dummies(skew=1)),
    ])

# %%
#【参考】
full_pipe = pipe.fit_transform(full)

full_pipe.shape
# Out:
# (2917, 426)

# %%
full_pipe_copy0=full_pipe.copy()

# %%
#【参考】
n_train=train.shape[0]
X = full_pipe[:n_train]
test_X = full_pipe[n_train:]
y= train.SalePrice

X_scaled = scaler.fit(X).transform(X)
y_log = np.log(train.SalePrice)
test_X_scaled = scaler.transform(test_X)

# %%
#【更改】
#Feature Selection
lasso=Lasso(alpha=0.001)
lasso.fit(X_scaled,y_log)
FI_lasso = pd.DataFrame({"Feature Importance":lasso.coef_}, index=full_pipe.columns)
FI_lasso.sort_values("Feature Importance",ascending=False)
a10=FI_lasso.sort_values("Feature Importance",ascending=False)
a11=a10.loc[a10['Feature Importance']==0].index
for ln in a11:
    full_pipe.drop([ln],axis=1,inplace=True)

# %% [raw]
# 说明：这里对原方案特征的处理做了一个更改，去掉了lasso中重要系数为0的特征；
# 原因：理解到1000多的样本用不着410那么多的特征，会造成过拟合，同时无用的特征会干扰最后结果。
# 实验结果：在自己一开始的特征工程上去掉不重要的特征，效果有提升；但在kernel的数据特征上去掉系数小的特征，效果无提升

# %%
X_scaled.shape
# Out:
# (1458, 426)

# %%
#【更改】
n_train=train.shape[0]
X = full_pipe[:n_train]
test_X = full_pipe[n_train:]
y= train.SalePrice

X_scaled = scaler.fit(X).transform(X)
y_log = np.log(train.SalePrice)
test_X_scaled = scaler.transform(test_X)

pca = PCA(n_components=76)

X_scaled=pca.fit_transform(X_scaled)
test_X_scaled = pca.transform(test_X_scaled)

X_scaled.shape, test_X_scaled.shape
# Out:
# ((1458, 76), (1459, 76))

# %%
from keras.models import Sequential      
from keras.layers.core import Dense, Activation     
from keras.layers import Dropout
from keras.optimizers import SGD  
from keras.layers.advanced_activations import LeakyReLU  
from sklearn import preprocessing  
#from keras.utils.visualize_plots import figures  
import matplotlib.pyplot as plt  
import numpy as np      
from keras.models import Model
from keras.layers import Input
# Out:
# Using TensorFlow backend.

# %%
#【self】
#说明这里手动切分了下样本，一开始就是想尝试这样做一下，后面有收获
#(X_scaled,y_log)
from sklearn.cross_validation import train_test_split  
x_train0, x_test0, y_train0, y_test0 = train_test_split(X_scaled,y_log, test_size=0.2, random_state=0)
x_train1, x_test1, y_train1, y_test1 = train_test_split(X_scaled,y_log, test_size=0.2, random_state=1)
x_train2, x_test2, y_train2, y_test2 = train_test_split(X_scaled,y_log, test_size=0.2, random_state=2)
x_train3, x_test3, y_train3, y_test3 = train_test_split(X_scaled,y_log, test_size=0.2, random_state=3)
x_train4, x_test4, y_train4, y_test4 = train_test_split(X_scaled,y_log, test_size=0.2, random_state=4)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train4.shape
# Out:
# (1166, 76)

# %%
#【self】反复调整过batch_size，和nb_epoch，不过都是手动调整，nb_epoch感觉可以直接打出来看，然后选择合适的nb_epoch
#callbacks这里还没有用
import keras
keras.callbacks.TensorBoard(log_dir='D:/py/class/a.logs', histogram_freq=0, write_graph=True, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)
#keras.callbacks.ModelCheckpoint('D:/py/class', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)
model_0 = Sequential() 
model_0.add(Dense(76,init='normal', input_dim=76))  #91 100 50 20 1  #410 50 5 1
#model.add(Dropout(0.2, input_shape=(60,)))
model_0.add(Activation('relu')) 
model_0.add(Dense(38,init='normal')) 
model_0.add(Activation('linear'))
#model_0.add(Dropout(0.5))
#model.add(Dense(50,init='normal')) 
#model.add(Activation('relu'))  
#model.add(Dense(15,init='normal')) 
#model.add(Activation('relu'))  
#model.add(Dense(5,init='normal')) 
#model.add(Activation('relu'))  
model_0.add(Dense(5,init='normal')) 
model_0.add(Activation('relu'))  
model_0.add(Dense(1))  
model_0.add(Activation('relu'))
model_0.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae'])  

#keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, verbose=0, mode='auto')
#

# %%
#【self】
hist0 = model_0.fit(x_train0, y_train0, batch_size=4, nb_epoch=2186, shuffle=True,verbose=0,validation_data=(x_test0, y_test0)) 
hist1 = model_0.fit(x_train1, y_train1, batch_size=4, nb_epoch=2186, shuffle=True,verbose=0,validation_data=(x_test1, y_test1)) 
hist2 = model_0.fit(x_train2, y_train2, batch_size=4, nb_epoch=2186, shuffle=True,verbose=0,validation_data=(x_test2, y_test2)) 
hist3 = model_0.fit(x_train3, y_train3, batch_size=4, nb_epoch=2186, shuffle=True,verbose=0,validation_data=(x_test3, y_test3)) 
hist4 = model_0.fit(x_train4, y_train4, batch_size=4, nb_epoch=2186, shuffle=True,verbose=0,validation_data=(x_test4, y_test4))

# %%
#【self】查看rmse损失
sa0=np.sqrt(hist0.history['loss'])
sc0=np.sqrt(hist0.history['val_loss'])

sa1=np.sqrt(hist1.history['loss'])
sc1=np.sqrt(hist1.history['val_loss'])

sa2=np.sqrt(hist2.history['loss'])
sc2=np.sqrt(hist2.history['val_loss'])

sa3=np.sqrt(hist3.history['loss'])
sc3=np.sqrt(hist3.history['val_loss'])

sa4=np.sqrt(hist4.history['loss'])
sc4=np.sqrt(hist4.history['val_loss'])

sa=(sa0+sa1+sa2+sa3+sa4)/5
sc=(sc0+sc1+sc2+sc3+sc4)/5

# %%
#【self】
dnn_loss=pd.DataFrame({'loss':sa, 'val_loss':sc})
dnn_loss.to_csv("dnn_loss.csv",index=False)

# %%
sc0
# Out:
# array([ 0.11215339,  0.12088426,  0.11282202, ...,  0.13019036,
#         0.13724229,  0.13047601])

# %%
sc1
# Out:
# array([ 0.11215339,  0.12088426,  0.11282202, ...,  0.13019036,
#         0.13724229,  0.13047601])

# %%
sc2
# Out:
# array([ 0.05671426,  0.05883565,  0.05710234, ...,  0.09385972,
#         0.09332552,  0.09585498])

# %%
sc3
# Out:
# array([ 0.04162661,  0.04332636,  0.04320658, ...,  0.07395665,
#         0.07283506,  0.07370903])

# %%
dnn_loss.head(5)
# Out:
#        loss  val_loss
# 0  1.282833  0.253723
# 1  0.198997  0.192869
# 2  0.154455  0.194564
# 3  0.134481  0.160413
# 4  0.122659  0.154053

# %%
dnn_loss.tail(5)
# Out:
#           loss  val_loss
# 2181  0.019432  0.115082
# 2182  0.019133  0.117157
# 2183  0.019294  0.118248
# 2184  0.019214  0.116675
# 2185  0.019341  0.116272

# %%
这里就发现一些问题
（1）sc0-sc4记录的是每次全部数据跑完后的loss，发现其实效果很一般，单独查看s0-s4发现不同切分样本的结果测试loss相差很大
（2）总体上来说是处于过拟合状态，训练集loss和验证集loss差很多，打印出来看过总体val_loss的趋势，感觉还在慢慢降

# %%
#【self】
hist3 = model_0.fit(x_train3, y_train3, batch_size=4, nb_epoch=3, shuffle=True,verbose=0,validation_data=(x_test3, y_test3))

# %%
np.sqrt(hist3.history['val_loss'])

# %%
np.sqrt(hist3.history['loss'])
# Out:
# array([0.34873707, 0.34588517, 0.33768649])

# %%
单独查看了每个样本训练的模型，有个别切分在训练集和测试集都表现很好。
此时分析过拟合应该是模型参数太多、太复杂引起的

# %%
遇到过在训练集和验证集的误差都很小，且只需训练一个epoch，也没有过拟合，看来和训练数据的切分也有关系
但是此时提交的结果为0.14408

# %%
现在有两个突出问题：一个是训练集过拟合，一个是测试集的损失也不是很好
解决过拟合方案：试过droupout，在输入层和中间层都加过，能解决一部分问题
解决第二个问题：换模型结构

# %%
#【self】
import keras
#keras.callbacks.TensorBoard(log_dir='D:/py/class/a.logs', histogram_freq=0, write_graph=True, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)
#keras.callbacks.ModelCheckpoint('D:/py/class', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', period=1)
model_1 = Sequential() 
model_1.add(Dense(76,init='normal', input_dim=76))  #91 100 50 20 1  #410 50 5 1
#model.add(Dropout(0.2, input_shape=(60,)))
model_1.add(Activation('relu')) 
model_1.add(Dense(38,init='normal')) 
model_1.add(Activation('linear'))
model_1.add(Dropout(0.5))
#model.add(Dense(50,init='normal')) 
#model.add(Activation('relu'))  
#model.add(Dense(15,init='normal')) 
#model.add(Activation('relu'))  
#model.add(Dense(5,init='normal')) 
#model.add(Activation('relu'))  
model_1.add(Dense(5,init='normal')) 
model_1.add(Activation('relu'))  
model_1.add(Dense(1))  
model_1.add(Activation('relu'))
model_1.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae'])  
hist3 = model_1.fit(x_train3, y_train3, batch_size=4, nb_epoch=70, shuffle=True,verbose=0,validation_data=(x_test3, y_test3))

# %%
np.sqrt(hist3.history['val_loss'])
# Out:
# array([ 1.12101438,  0.98352583,  0.82639689,  0.89252354,  0.92464373,
#         1.14519154,  0.80072985,  0.80037757,  0.99714449,  0.89622347,
#         0.69894364,  0.73312046,  0.7911666 ,  0.64621328,  0.56663125,
#         0.61458871,  0.57417802,  0.99993259,  0.55902599,  0.77885355,
#         0.53308385,  0.70905947,  0.46429665,  0.73378041,  0.54351781,
#         0.64929504,  0.45266647,  0.4900723 ,  0.48935818,  0.49124982,
#         0.88170869,  0.61435835,  0.44476388,  0.34711139,  0.38332059,
#         0.38138413,  0.78517776,  0.27111378,  0.32274069,  0.32639431,
#         0.36136723,  0.32460335,  0.20277888,  0.21705137,  0.19104542,
#         0.15540929,  0.14284061,  0.16944174,  0.1408539 ,  0.12265827,
#         0.12571545,  0.12442959,  0.13477919,  0.12703442,  0.12036552,
#         0.12366665,  0.12266297,  0.11879941,  0.11904085,  0.11862367,
#         0.1367607 ,  0.11644501,  0.1183405 ,  0.13203604,  0.12518014,
# ...

# %%
这里调整查看nb_epoch的趋势，选择70；
但是相比之前有提升
提交结果到了0.12966，

# %%
#【self】
###也用sklearn的KerasRegressor接口写了GridSearchCV进行了网格搜索..跑得太慢了，没等
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.grid_search import GridSearchCV
#这里必须要creat一下
def create_model():
    # create model
    model_3 = Sequential() 
    model_3.add(Dense(76,init='normal', input_dim=76))  #91 100 50 20 1  #410 50 5 1
#model.add(Dropout(0.2, input_shape=(60,)))
    model_3.add(Activation('relu')) 
    model_3.add(Dense(38,init='normal')) 
    model_3.add(Activation('linear'))
    model_3.add(Dropout(0.5))
#model.add(Dense(50,init='normal')) 
#model.add(Activation('relu'))  
#model.add(Dense(15,init='normal')) 
#model.add(Activation('relu'))  
#model.add(Dense(5,init='normal')) 
#model.add(Activation('relu'))  
    model_3.add(Dense(5,init='normal')) 
    model_3.add(Activation('relu'))  
    model_3.add(Dense(1))  
    model_3.add(Activation('relu'))
    model_3.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae']) 
    return model_3
model = KerasRegressor(build_fn=create_model, verbose=0)
batch_size = [1, 2, 4, 8]
epochs = [1,3,5,10,20,30,50,60,80,100,150,200,400,600,1000]
param_grid = dict(batch_size=batch_size, nb_epoch=epochs)
grid = GridSearchCV(estimator=model, param_grid=param_grid,scoring='neg_mean_squared_error',cv=5, n_jobs=-1)
grid_result = grid.fit(X_scaled,y_log)
#print(grid_result.best_params_, np.sqrt(-grid_result.best_score_))
#grid_result.cv_results_['mean_test_score'] = np.sqrt(-grid_result.cv_results_['mean_test_score'])
#print(pd.DataFrame(grid_result.cv_results_)[['params','mean_test_score','std_test_score']])
# Out:
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
#【self】试着用函数式搭建一个模型，重要度非0的特征直接输入，重要度为0的特征当做辅助输入
import keras
from keras.layers import Input, Dense
from keras.models import Model
main_input = Input(shape=(76,), dtype='float32', name='main_input')
xm = Dense(76, activation='relu')(main_input)
auxiliary_input = Input(shape=(350,),dtype='float32', name='aux_input')
# We stack a deep densely-connected network on top
x0 = Dense(350, activation='relu')(auxiliary_input)
x = Dense(50, activation='linear')(x0)
x2 = Dense(5, activation='relu')(x)
x3 = keras.layers.concatenate([x2, xm])
x4 = Dense(5, activation='relu')(x3)
M_output = Dense(1, activation='relu', name='main_output')(x4)
model = Model(inputs=[main_input, auxiliary_input], outputs=M_output)
model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae'])

# %%
#【self】将特征按照重要度切分成main 和 aux组
n_train=train.shape[0]
X_all = full_pipe_copy0[:n_train]
test_X_all = full_pipe_copy0[n_train:]
y= train.SalePrice

X_scaled_all = scaler.fit(X_all).transform(X_all)
y_log = np.log(train.SalePrice)
test_X_scaled_all = scaler.transform(test_X_all)

#pca = PCA(n_components=76)

X_scaled=pca.fit_transform(X_scaled)
test_X_scaled = pca.transform(test_X_scaled)

X_scaled.shape, test_X_scaled.shape

#
#Feature split
lasso=Lasso(alpha=0.001)
lasso.fit(X_scaled_all,y_log)
FI_lasso = pd.DataFrame({"Feature Importance":lasso.coef_}, index=full_pipe_copy0.columns)
FI_lasso.sort_values("Feature Importance",ascending=False)
a10=FI_lasso.sort_values("Feature Importance",ascending=False)

a11_0=a10.loc[a10['Feature Importance']!=0].index
main_feature=full_pipe_copy0.loc[:,a11_0]
X_main = main_feature[:n_train]
test_X_main = main_feature[n_train:]

X_scaled_main = scaler.fit(X_main).transform(X_main)
test_X_scaled_main = scaler.transform(test_X_main)


a11=a10.loc[a10['Feature Importance']==0].index
aux_feature=full_pipe_copy0.loc[:,a11]
X_aux = aux_feature[:n_train]
test_X_aux = aux_feature[n_train:]

X_scaled_aux = scaler.fit(X_aux).transform(X_aux)
test_X_scaled_aux = scaler.transform(test_X_aux)

X_scaled_main.shape,test_X_scaled_main.shape,      X_scaled_aux.shape,test_X_scaled_aux.shape
# Out:
# ((1458, 76), (1459, 76), (1458, 350), (1459, 350))

# %%
type(X_scaled_main[0][0])
# Out:
# numpy.float64

# %%
hist=model.fit([X_scaled_main, X_scaled_aux], y_log,
          epochs=2, batch_size=16,validation_split=0.5)
# Out:
# Train on 729 samples, validate on 729 samples
# Epoch 1/2
# 729/729 [==============================] - 0s 139us/step - loss: 0.0052 - mean_absolute_error: 0.0614 - val_loss: 0.0060 - val_mean_absolute_error: 0.0658
# Epoch 2/2
# 729/729 [==============================] - 0s 128us/step - loss: 0.0051 - mean_absolute_error: 0.0604 - val_loss: 0.0021 - val_mean_absolute_error: 0.0342

# %%
np.sqrt(hist.history['loss'])
# Out:
# array([ 0.07204962,  0.07157485])

# %%
np.sqrt(hist.history['val_loss'])
# Out:
# array([ 0.07714433,  0.04571591])

# %%
说明：batch_size仍然是手动调，epochs可以从打印的过程中查看。
经过一顿操作，调试结构过程中发现训练集损失下降不如之前的全连接网络，模型学习500次后基本不下降，amse 0.07，之前是0.01左右
用了validation_split=0.5，希望能提高泛化能力，尝试结果如上图，测试集和训练集结果都挺好，但是提交之后的结果是0.2。。。

# %%
#提交代码
y_v=model.predict([test_X_scaled_main,test_X_scaled_aux])
pred = np.exp(y_v)
pred_list=[pred[i][0] for i in range(len(pred))]
result=pd.DataFrame({'Id':test.Id, 'SalePrice':pred_list})
result.to_csv("submission_dnn_m.csv",index=False)

# %%
#画图
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend(['Training', 'Validation'])
#地下这个图说明训练两次之后，模型loss可以下降到不错的地方，训练次数增加，loss基本没有什么变化

# %%
test = pd.read_csv('test.csv')

# %%
#续灌模型的预测输出代码
y_v=model_1.predict(test_X_scaled)
pred = np.exp(y_v)
pred_list=[pred[i][0] for i in range(len(pred))]
result=pd.DataFrame({'Id':test.Id, 'SalePrice':pred_list})
result.to_csv("submission_dnn.csv",index=False)

# %%
###########################
后面的部分是机器学习的部分，用的是copy的代码，就是简单的网格搜索交叉验证，在原代码基础上加了一个RNN的融合
还没有融合自己的方案时，用76个特征在原代码上本地交叉验证的结果优于原kernal，但是提交之后的结果不如原kernal,  end: 0.114
###########################

# %%
import xgboost as xgb

# %%
#专门跑了xgboost的网格搜索，效果还不如一般的机器学习方法 
from sklearn.model_selection import KFold, train_test_split, GridSearchCV
print('Parameter optimization')
model = xgb.XGBRegressor()
clf = GridSearchCV(model,
                   {'max_depth': [4,5,6],
                    'learning_rate':[0.01,0.05,0.1],
                    'n_estimators': [300,500,800]},
                   scoring='neg_mean_squared_error',
                   cv=5,  
                   verbose=1)
clf.fit(X_scaled, y_log)
print(np.sqrt(-clf.best_score_))
print(clf.best_params_)
# Out:
# Parameter optimization
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [Parallel(n_jobs=1)]: Done 135 out of 135 | elapsed:  7.8min finished
# 0.12074339007170408
# {'max_depth': 4, 'n_estimators': 800, 'learning_rate': 0.05}

# %%
#【参考】
# define cross validation strategy
def rmse_cv(model,X,y):
    rmse = np.sqrt(-cross_val_score(model, X, y, scoring="neg_mean_squared_error", cv=5))
    return rmse

# %%
LinearRegression
Ridge
Lasso
Random Forrest
Gradient Boosting Tree
Support Vector Regression
Linear Support Vector Regression
ElasticNet
Stochastic Gradient Descent
BayesianRidge
KernelRidge
ExtraTreesRegressor
XgBoost

# %%
#用410个特征在这里进行训练，lr的loss非常大，大于1，用76特征进行训练，loss有改进
models = [LinearRegression(),Ridge(),Lasso(alpha=0.01,max_iter=10000),RandomForestRegressor(),GradientBoostingRegressor(),SVR(),LinearSVR(),
          ElasticNet(alpha=0.001,max_iter=10000),SGDRegressor(max_iter=1000,tol=1e-3),BayesianRidge(),KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5),
          ExtraTreesRegressor()]

names = ["LR", "Ridge", "Lasso", "RF", "GBR", "SVR", "LinSVR", "Ela","SGD","Bay","Ker","Extra","Xgb"]
for name, model in zip(names, models):
    score = rmse_cv(model, X_scaled, y_log)
    print("{}: {:.6f}, {:.4f}".format(name,score.mean(),score.std()))
# Out:
# LR: 0.104690, 0.0058
# Ridge: 0.104629, 0.0058
# Lasso: 0.121572, 0.0052
# RF: 0.141408, 0.0065
# GBR: 0.121974, 0.0040
# SVR: 0.116225, 0.0068
# LinSVR: 0.105190, 0.0061
# Ela: 0.105341, 0.0058
# SGD: 0.139354, 0.0156
# Bay: 0.104738, 0.0055
# Ker: 0.104192, 0.0050
# Extra: 0.134465, 0.0020

# %%
#【参考】
class grid():
    def __init__(self,model):
        self.model = model
    
    def grid_get(self,X,y,param_grid):
        grid_search = GridSearchCV(self.model,param_grid,cv=5, scoring="neg_mean_squared_error")
        grid_search.fit(X,y)
        print(grid_search.best_params_, np.sqrt(-grid_search.best_score_))
        grid_search.cv_results_['mean_test_score'] = np.sqrt(-grid_search.cv_results_['mean_test_score'])
        print(pd.DataFrame(grid_search.cv_results_)[['params','mean_test_score','std_test_score']])

# %%
grid(Lasso()).grid_get(X_scaled,y_log,{'alpha': [0.0004,0.0005,0.0007,0.0009],'max_iter':[10000]})
# Out:
# {'max_iter': 10000, 'alpha': 0.0005} 0.111583489829
#                                  params  mean_test_score  std_test_score
# 0  {'max_iter': 10000, 'alpha': 0.0004}         0.111694        0.001420
# 1  {'max_iter': 10000, 'alpha': 0.0005}         0.111583        0.001371
# 2  {'max_iter': 10000, 'alpha': 0.0007}         0.111882        0.001300
# 3  {'max_iter': 10000, 'alpha': 0.0009}         0.112266        0.001213

# %%
grid(Ridge()).grid_get(X_scaled,y_log,{'alpha':[35,40,45,50,55,60,65,70,80,90]})
# Out:
# {'alpha': 60} 0.110181394789
#           params  mean_test_score  std_test_score
# 0  {'alpha': 35}         0.110353        0.001273
# 1  {'alpha': 40}         0.110284        0.001254
# 2  {'alpha': 45}         0.110237        0.001239
# 3  {'alpha': 50}         0.110206        0.001227
# 4  {'alpha': 55}         0.110189        0.001217
# 5  {'alpha': 60}         0.110181        0.001209
# 6  {'alpha': 65}         0.110183        0.001202
# 7  {'alpha': 70}         0.110192        0.001197
# 8  {'alpha': 80}         0.110227        0.001188
# 9  {'alpha': 90}         0.110281        0.001182

# %%
grid(SVR()).grid_get(X_scaled,y_log,{'C':[11,13,15],'kernel':["rbf"],"gamma":[0.0003,0.0004],"epsilon":[0.008,0.009]})
# Out:
# {'kernel': 'rbf', 'C': 15, 'gamma': 0.0004, 'epsilon': 0.008} 0.108140725147
#                                                params  mean_test_score  \
# 0   {'kernel': 'rbf', 'C': 11, 'gamma': 0.0003, 'e...         0.108625
# 1   {'kernel': 'rbf', 'C': 11, 'gamma': 0.0004, 'e...         0.108269
# 2   {'kernel': 'rbf', 'C': 11, 'gamma': 0.0003, 'e...         0.108574
# 3   {'kernel': 'rbf', 'C': 11, 'gamma': 0.0004, 'e...         0.108235
# 4   {'kernel': 'rbf', 'C': 13, 'gamma': 0.0003, 'e...         0.108538
# 5   {'kernel': 'rbf', 'C': 13, 'gamma': 0.0004, 'e...         0.108172
# 6   {'kernel': 'rbf', 'C': 13, 'gamma': 0.0003, 'e...         0.108512
# 7   {'kernel': 'rbf', 'C': 13, 'gamma': 0.0004, 'e...         0.108149
# 8   {'kernel': 'rbf', 'C': 15, 'gamma': 0.0003, 'e...         0.108471
# 9   {'kernel': 'rbf', 'C': 15, 'gamma': 0.0004, 'e...         0.108141
# 10  {'kernel': 'rbf', 'C': 15, 'gamma': 0.0003, 'e...         0.108448
# ...

# %%
param_grid={'alpha':[0.2,0.3,0.4], 'kernel':["polynomial"], 'degree':[3],'coef0':[0.8,1]}
grid(KernelRidge()).grid_get(X_scaled,y_log,param_grid)
# Out:
# {'alpha': 0.2, 'coef0': 0.8, 'degree': 3, 'kernel': 'polynomial'} 0.108170914572
#                                               params  mean_test_score  \
# 0  {'alpha': 0.2, 'coef0': 0.8, 'degree': 3, 'ker...         0.108171
# 1  {'alpha': 0.2, 'coef0': 1, 'degree': 3, 'kerne...         0.108396
# 2  {'alpha': 0.3, 'coef0': 0.8, 'degree': 3, 'ker...         0.108316
# 3  {'alpha': 0.3, 'coef0': 1, 'degree': 3, 'kerne...         0.108183
# 4  {'alpha': 0.4, 'coef0': 0.8, 'degree': 3, 'ker...         0.108688
# 5  {'alpha': 0.4, 'coef0': 1, 'degree': 3, 'kerne...         0.108216
#
#    std_test_score
# 0        0.001216
# 1        0.001253
# 2        0.001193
# 3        0.001217
# 4        0.001185
# 5        0.001197

# %%
grid(ElasticNet()).grid_get(X_scaled,y_log,{'alpha':[0.0008,0.004,0.005],'l1_ratio':[0.08,0.1,0.3],'max_iter':[10000]})
# Out:
# {'max_iter': 10000, 'alpha': 0.005, 'l1_ratio': 0.08} 0.111392365127
#                                               params  mean_test_score  \
# 0  {'max_iter': 10000, 'alpha': 0.0008, 'l1_ratio...         0.114770
# 1  {'max_iter': 10000, 'alpha': 0.0008, 'l1_ratio...         0.114279
# 2  {'max_iter': 10000, 'alpha': 0.0008, 'l1_ratio...         0.112140
# 3  {'max_iter': 10000, 'alpha': 0.004, 'l1_ratio'...         0.111465
# 4  {'max_iter': 10000, 'alpha': 0.004, 'l1_ratio'...         0.111432
# 5  {'max_iter': 10000, 'alpha': 0.004, 'l1_ratio'...         0.112686
# 6  {'max_iter': 10000, 'alpha': 0.005, 'l1_ratio'...         0.111392
# 7  {'max_iter': 10000, 'alpha': 0.005, 'l1_ratio'...         0.111467
# 8  {'max_iter': 10000, 'alpha': 0.005, 'l1_ratio'...         0.113078
#
#    std_test_score
# 0        0.001962
# 1        0.001920
# 2        0.001618
# 3        0.001414
# 4        0.001352
# 5        0.001169
# 6        0.001337
# 7        0.001305
# 8        0.001164

# %%
#【参考】
class AverageWeight(BaseEstimator, RegressorMixin):
    def __init__(self,mod,weight):
        self.mod = mod
        self.weight = weight
        
    def fit(self,X,y):
        self.models_ = [clone(x) for x in self.mod]
        for model in self.models_:
            model.fit(X,y)
        return self
    
    def predict(self,X):
        w = list()
        pred = np.array([model.predict(X) for model in self.models_])
        # for every data point, single model prediction times weight, then add them together
        for data in range(pred.shape[1]):
            single = [pred[model,data]*weight for model,weight in zip(range(pred.shape[0]),self.weight)]
            w.append(np.sum(single))
        return w

lasso = Lasso(alpha=0.0005,max_iter=10000)
ridge = Ridge(alpha=60)
svr = SVR(gamma= 0.0004,kernel='rbf',C=13,epsilon=0.009)
ker = KernelRidge(alpha=0.2 ,kernel='polynomial',degree=3 , coef0=0.8)
ela = ElasticNet(alpha=0.005,l1_ratio=0.08,max_iter=10000)
bay = BayesianRidge()

# assign weights based on their gridsearch score
w1 = 0.02
w2 = 0.2
w3 = 0.25
w4 = 0.3
w5 = 0.03
w6 = 0.2

weight_avg = AverageWeight(mod = [lasso,ridge,svr,ker,ela,bay],weight=[w1,w2,w3,w4,w5,w6])

score = rmse_cv(weight_avg,X_scaled,y_log)
print(score.mean())
# Out:
# 0.10383078314743795

# %%
#【参考】
class stacking(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self,mod,meta_model):
        self.mod = mod
        self.meta_model = meta_model
        self.kf = KFold(n_splits=5, random_state=42, shuffle=True)
        
    def fit(self,X,y):
        self.saved_model = [list() for i in self.mod]
        oof_train = np.zeros((X.shape[0], len(self.mod)))
        
        for i,model in enumerate(self.mod):
            for train_index, val_index in self.kf.split(X,y):
                renew_model = clone(model)
                renew_model.fit(X[train_index], y[train_index])
                self.saved_model[i].append(renew_model)
                oof_train[val_index,i] = renew_model.predict(X[val_index])
        
        self.meta_model.fit(oof_train,y)
        return self
    
    def predict(self,X):
        whole_test = np.column_stack([np.column_stack(model.predict(X) for model in single_model).mean(axis=1) 
                                      for single_model in self.saved_model]) 
        return self.meta_model.predict(whole_test)
    
    def get_oof(self,X,y,test_X):
        oof = np.zeros((X.shape[0],len(self.mod)))
        test_single = np.zeros((test_X.shape[0],5))
        test_mean = np.zeros((test_X.shape[0],len(self.mod)))
        for i,model in enumerate(self.mod):
            for j, (train_index,val_index) in enumerate(self.kf.split(X,y)):
                clone_model = clone(model)
                clone_model.fit(X[train_index],y[train_index])
                oof[val_index,i] = clone_model.predict(X[val_index])
                test_single[:,j] = clone_model.predict(test_X)
            test_mean[:,i] = test_single.mean(axis=1)
        return oof, test_mean

# %%
#【参考】
# must do imputer first, otherwise stacking won't work, and i don't know why.
a = Imputer().fit_transform(X_scaled)
b = Imputer().fit_transform(y_log.values.reshape(-1,1)).ravel()

stack_model = stacking(mod=[lasso,ridge,svr,ker,ela,bay],meta_model=ker)

score = rmse_cv(stack_model,a,b)
print(score.mean())
# Out:
# 0.10358081008531661

# %%
#[ADD]
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.grid_search import GridSearchCV
#这里必须要creat一下
def create_model():
    # create model
    model_3 = Sequential() 
    model_3.add(Dense(76,init='normal', input_dim=76))  #91 100 50 20 1  #410 50 5 1
#model.add(Dropout(0.2, input_shape=(60,)))
    model_3.add(Activation('relu')) 
    model_3.add(Dense(38,init='normal')) 
    model_3.add(Activation('linear'))
    model_3.add(Dropout(0.5))
#model.add(Dense(50,init='normal')) 
#model.add(Activation('relu'))  
#model.add(Dense(15,init='normal')) 
#model.add(Activation('relu'))  
#model.add(Dense(5,init='normal')) 
#model.add(Activation('relu'))  
    model_3.add(Dense(5,init='normal')) 
    model_3.add(Activation('relu'))  
    model_3.add(Dense(1))  
    model_3.add(Activation('relu'))
    model_3.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae']) 
    return model_3
#param = dict(batch_size=4, nb_epoch=70,score='neg_mean_squared_error')
model_kr = KerasRegressor(build_fn=create_model, batch_size=4, nb_epoch=70,verbose=0)

# %%
# must do imputer first, otherwise stacking won't work, and i don't know why.
a = Imputer().fit_transform(X_scaled)
b = Imputer().fit_transform(y_log.values.reshape(-1,1)).ravel()
stack_model = stacking(mod=[model_kr,lasso,ridge,svr,ker,ela,bay],meta_model=ker)

score = rmse_cv(stack_model,a,b)
print(score.mean())
# Out:
# 0.10406298058238775

# %%
#[ADD]#[ADD]只融合dnn和ela，提交成绩0.118；只融合dnn、svr 0.117；
# 
stack_model = stacking(mod=[model_kr,lasso,ridge,svr,ker,ela,bay],meta_model=ker)
stack_model.fit(a,b)
# Out:
# stacking(meta_model=KernelRidge(alpha=0.2, coef0=0.8, degree=3, gamma=None, kernel='polynomial',
#       kernel_params=None),
#      mod=[<keras.wrappers.scikit_learn.KerasRegressor object at 0x7f8c31105dd8>, Lasso(alpha=0.0005, copy_X=True, fit_intercept=True, max_iter=10000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False), Ridge(alpha=60, copy_X=True,...True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)])

# %%
pred = np.exp(stack_model.predict(test_X_scaled))

result=pd.DataFrame({'Id':test.Id, 'SalePrice':pred})
result.to_csv("submission.csv",index=False)

# %%
from IPython.display import Image
Image(filename='abc.png', width=400)

# %%
Image(filename='abcd.png', width=400) 
best 0.11419
